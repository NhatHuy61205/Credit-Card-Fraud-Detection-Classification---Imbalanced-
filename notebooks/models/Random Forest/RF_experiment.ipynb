# %% [markdown]
# ### Phạm Hoàng Duy

# %%
import pandas as pd
# Out:
# Running cells with '.venv (Python 3.14.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/BTL AI/Credit-Card-Fraud-Detection-Classification---Imbalanced-/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
